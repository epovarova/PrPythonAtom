# %%
from flask import Flask, request, jsonify, render_template
from heap import MinHeap
import copy

app = Flask(__name__)

class PrefixTreeNode:
    def __init__(self,string = None, json = None, frequency = 1):
        self.json = json
        self.string = string
        self.frequency = frequency
    def __lt__(self, other):
        if self.frequency < other.frequency:
            return True
        return False        
    def __gt__(self, other):
        if self.frequency > other.frequency:
            return True
        return False 
    def __le__(self, other):
        if self.frequency <= other.frequency:
            return True
        return False        
    def __ge__(self, other):
        if self.frequency >= other.frequency:
            return True
        return False
class PrefixTree:
    #TODO реализация класса prefix tree, методы как на лекции + метод дать топ 10 продолжений. Скажем на строку кросс выдаем кроссовки, кроссовочки итп. Как хранить топ? 
    #Решать вам. Можно, конечно, обходить все ноды, но это долго. Дешевле чуток проиграть по памяти, зато отдавать быстро (скажем можно взять кучу)
    #В терминальных (конечных) нодах может лежать json с топ актерами.
    def __init__(self):
        self.root = [{}]
        
    #def __get__(self, key):
    #    return self.children[key]
        
    def add(self, string = None, json = None, frequency = 1):
        if self.check(string):
            return
        wrk_dict = self.root
        
        for i in string:
            if i in wrk_dict[0]:
                wrk_dict = wrk_dict[0][i]
            else:
                wrk_dict[0][i] = [{}, MinHeap([])]
                wrk_dict = wrk_dict[0][i]
            node = PrefixTreeNode(string, json, frequency)
            if len(wrk_dict[1].array) < 10:
                wrk_dict[1].add(node)
            else:
                min_node = wrk_dict[1].extract_minimum()
                if node.frequency > min_node.frequency:
                    wrk_dict[1].add(node)
                else:
                    wrk_dict[1].add(min_node)
        wrk_dict.append(json)        
        
    def check(self, string):        
        wrk_dict = self.root
        for i in string:
            if i in wrk_dict[0]:
                wrk_dict = wrk_dict[0][i]
            else:
                return False
        if len(wrk_dict) == 3:
            return True
        return False
    
    def check_part(self, string):
        wrk_dict = self.root
        for i in string:
            if i in wrk_dict[0]:
                wrk_dict = wrk_dict[0][i]
            else:
                return False
        return True
    
    def top10(self, string):
        top = []
        if self.check_part(string):
            wrk_dict = self.root
            for i in string:
                wrk_dict = wrk_dict[0][i]
            node_array = copy(wrk_dict[1].array)
            node_array.sort(reverse = True)
            for i in node_array:
                sudgest = {'sudgest': s.string, 'json': s.json}
                top.append(sudgest)
        return top
        

def init_prefix_tree(filename):
    #TODO в данном методе загружаем данные из файла. Предположим вормат файла "Строка, чтобы положить в дерево" \t "json значение для ноды" \t частота встречаемости
    f = open(filename, 'r')
    for line in f:
        data = line.split('\t')
        PrefixTree.add(data[0], data[1], data[2])
    f.close()

# %%
import pandas as pd
data = pd.read_pickle('parser_data.pkl')
df_pkl = pd.DataFrame(data)
title = []
title = df_pkl.Title

# %%
pTree = PrefixTree()
for i in title:
    pTree.add(i)
pTree.root[0]
# Out:
# {'«': [{'Б': [{'р': [{'е': [{'с': [{'т': [{'с': [{'к': [{'а': [{'я': [{' ': [{'к': [{'р': [{'е': [{'п': [{'о': [{'с': [{'т': [{'ь': [{'»': [{},
#                                         <heap.MinHeap at 0x7fba5b8d9898>,
#                                         None]},
#                                       <heap.MinHeap at 0x7fba5b8d92e8>]},
#                                     <heap.MinHeap at 0x7fba5b8d9438>]},
#                                   <heap.MinHeap at 0x7fba5b8d9e10>]},
#                                 <heap.MinHeap at 0x7fba5b8d9780>]},
#                               <heap.MinHeap at 0x7fba676c4e10>]},
#                             <heap.MinHeap at 0x7fba676c4b38>]},
#                           <heap.MinHeap at 0x7fba676c40f0>]},
#                         <heap.MinHeap at 0x7fba676c4f98>]},
#                       <heap.MinHeap at 0x7fba57c215c0>]},
#                     <heap.MinHeap at 0x7fba67676b00>]},
#                   <heap.MinHeap at 0x7fba67676278>]},
#                 <heap.MinHeap at 0x7fba5bff83c8>]},
#               <heap.MinHeap at 0x7fba5b72ff98>]},
#             <heap.MinHeap at 0x7fba5b72ff28>]},
#           <heap.MinHeap at 0x7fba5b72f160>]},
#         <heap.MinHeap at 0x7fba5b72f710>]},
#       <heap.MinHeap at 0x7fba5b72f6d8>]},
#     <heap.MinHeap at 0x7fba5bd96198>],
#    'М': [{'о': [{'с': [{'к': [{'в': [{'а': [{'-': [{'С': [{'и': [{'т': [{'и': [{'»': [{},
#                           <heap.MinHeap at 0x7fba5bff92e8>,
#                           None]},
#                         <heap.MinHeap at 0x7fba5b3829b0>]},
#                       <heap.MinHeap at 0x7fba5b382518>]},
#                     <heap.MinHeap at 0x7fba5b3824e0>]},
#                   <heap.MinHeap at 0x7fba5b3827b8>]},
#                 <heap.MinHeap at 0x7fba5b382da0>]},
#               <heap.MinHeap at 0x7fba5b382b70>]},
#             <heap.MinHeap at 0x7fba5ed3fef0>]},
#           <heap.MinHeap at 0x7fba5ed3f320>]},
#         <heap.MinHeap at 0x7fba5ed3f7f0>]},
#       <heap.MinHeap at 0x7fba5ed3fe48>]},
#     <heap.MinHeap at 0x7fba66761b38>]},
#   <heap.MinHeap at 0x7fba5bd96e80>],
#  'А': [{'л': [{'я': [{'с': [{'к': [{'а': [{},
#             <heap.MinHeap at 0x7fba5bffcb00>,
#             None]},
#           <heap.MinHeap at 0x7fba5bffc518>]},
#         <heap.MinHeap at 0x7fba52f36710>]},
#       <heap.MinHeap at 0x7fba5a4bb898>]},
#     <heap.MinHeap at 0x7fba5a4bb5c0>],
#    'р': [{'а': [{'л': [{'ь': [{'с': [{'к': [{'о': [{'е': [{' ': [{'м': [{'о': [{'р': [{'е': [{},
#                             <heap.MinHeap at 0x7fba64e08780>,
#                             None]},
#                           <heap.MinHeap at 0x7fba64e088d0>]},
#                         <heap.MinHeap at 0x7fba64e084e0>]},
#                       <heap.MinHeap at 0x7fba64e08860>]},
#                     <heap.MinHeap at 0x7fba64e086a0>]},
#                   <heap.MinHeap at 0x7fba5ceb3128>]},
#                 <heap.MinHeap at 0x7fba5ceb3710>]},
#               <heap.MinHeap at 0x7fba5ceb3dd8>]},
#             <heap.MinHeap at 0x7fba5ceb3d30>]},
#           <heap.MinHeap at 0x7fba5ceb3668>]},
#         <heap.MinHeap at 0x7fba5ceb31d0>]},
#       <heap.MinHeap at 0x7fba5ceb8390>],
#      'б': [{'а': [{'т': [{}, <heap.MinHeap at 0x7fba5a4cd908>, None]},
#         <heap.MinHeap at 0x7fba5a4cd3c8>]},
#       <heap.MinHeap at 0x7fba5a4cdfd0>]},
#     <heap.MinHeap at 0x7fba5bffc828>]},
#   <heap.MinHeap at 0x7fba59626f98>],
#  'Б': [{'а': [{'л': [{'и': [{}, <heap.MinHeap at 0x7fba583c4588>, None]},
#       <heap.MinHeap at 0x7fba583c4208>]},
#     <heap.MinHeap at 0x7fba583c4b00>],
#    'и': [{'г': [{'-': [{'Б': [{'е': [{'н': [{},
#               <heap.MinHeap at 0x7fba6263be10>,
#               None]},
#             <heap.MinHeap at 0x7fba5b50a898>]},
#           <heap.MinHeap at 0x7fba5b50ad30>]},
#         <heap.MinHeap at 0x7fba5b50ac18>]},
#       <heap.MinHeap at 0x7fba5b50a438>]},
#     <heap.MinHeap at 0x7fba5b50a0b8>],
#    'о': [{'л': [{'ь': [{'ш': [{'о': [{'й': [{' ': [{'т': [{'е': [{'а': [{'т': [{'р': [{},
#                           <heap.MinHeap at 0x7fba5bd96be0>,
#                           None]},
#                         <heap.MinHeap at 0x7fba5bd96a20>]},
#                       <heap.MinHeap at 0x7fba5bd966a0>]},
#                     <heap.MinHeap at 0x7fba5bd96390>]},
#                   <heap.MinHeap at 0x7fba5a2f4e48>]},
#                 <heap.MinHeap at 0x7fba5a2f4160>]},
#               <heap.MinHeap at 0x7fba5a2f40b8>]},
#             <heap.MinHeap at 0x7fba5a2f4588>]},
#           <heap.MinHeap at 0x7fba5c68fb70>]},
#         <heap.MinHeap at 0x7fba5c68fd68>]},
#       <heap.MinHeap at 0x7fba5c68f908>]},
#     <heap.MinHeap at 0x7fba5c68feb8>],
#    'р': [{'о': [{'д': [{'в': [{'е': [{'й': [{},
#               <heap.MinHeap at 0x7fba5b5f0c18>,
#               None]},
#             <heap.MinHeap at 0x7fba5b5f0630>]},
#           <heap.MinHeap at 0x7fba5b5f0208>]},
#         <heap.MinHeap at 0x7fba5b5f0080>]},
#       <heap.MinHeap at 0x7fba64e08d68>],
#      'у': [{'к': [{'л': [{'и': [{'н': [{},
#               <heap.MinHeap at 0x7fba5a9b1780>,
#               None]},
#             <heap.MinHeap at 0x7fba5a9b1588>]},
#           <heap.MinHeap at 0x7fba5a9b1320>]},
#         <heap.MinHeap at 0x7fba5a9b1198>]},
#       <heap.MinHeap at 0x7fba5a9b12e8>]},
#     <heap.MinHeap at 0x7fba5b8d96d8>],
#    'у': [{'к': [{'и': [{'н': [{'г': [{'е': [{'м': [{'с': [{'к': [{'и': [{'й': [{' ': [{'д': [{'в': [{'о': [{'р': [{'е': [{'ц': [{},
#                                       <heap.MinHeap at 0x7fba58c2c7b8>,
#                                       None]},
#                                     <heap.MinHeap at 0x7fba58c2cd30>]},
#                                   <heap.MinHeap at 0x7fba58c2ca90>]},
#                                 <heap.MinHeap at 0x7fba58c2c400>]},
#                               <heap.MinHeap at 0x7fba58c2cda0>]},
#                             <heap.MinHeap at 0x7fba58c2c160>]},
#                           <heap.MinHeap at 0x7fba5b2f9128>]},
#                         <heap.MinHeap at 0x7fba5b2f9b38>]},
#                       <heap.MinHeap at 0x7fba5b2f9940>]},
#                     <heap.MinHeap at 0x7fba5b2f9550>]},
#                   <heap.MinHeap at 0x7fba5b2f9240>]},
#                 <heap.MinHeap at 0x7fba584f0d30>]},
#               <heap.MinHeap at 0x7fba584f0710>]},
#             <heap.MinHeap at 0x7fba584f07b8>]},
#           <heap.MinHeap at 0x7fba584f0f60>]},
#         <heap.MinHeap at 0x7fba584f0390>]},
#       <heap.MinHeap at 0x7fba584f04a8>],
#      'р': [{'д': [{'ж': [{'-': [{'э': [{'л': [{'ь': [{'-': [{'А': [{'р': [{'а': [{'б': [{},
#                             <heap.MinHeap at 0x7fba5be8f320>,
#                             None]},
#                           <heap.MinHeap at 0x7fba5be8fb70>]},
#                         <heap.MinHeap at 0x7fba5be8fba8>]},
#                       <heap.MinHeap at 0x7fba5a9b3c88>]},
#                     <heap.MinHeap at 0x7fba5a9b3f98>]},
#                   <heap.MinHeap at 0x7fba5a9b3d68>]},
#                 <heap.MinHeap at 0x7fba5a9b3c18>]},
#               <heap.MinHeap at 0x7fba5a9b38d0>]},
#             <heap.MinHeap at 0x7fba5a9b3588>]},
#           <heap.MinHeap at 0x7fba583dd438>]},
#         <heap.MinHeap at 0x7fba583dd128>]},
#       <heap.MinHeap at 0x7fba583ddf60>]},
#     <heap.MinHeap at 0x7fba584f0588>]},
#   <heap.MinHeap at 0x7fba5b50aa58>],
#  'В': [{'е': [{'л': [{'и': [{'к': [{'а': [{'я': [{' ': [{'К': [{'и': [{'т': [{'а': [{'й': [{'с': [{'к': [{'а': [{'я': [{' ': [{'с': [{'т': [{'е': [{'н': [{'а': [{},
#                                               <heap.MinHeap at 0x7fba585e9dd8>,
#                                               None]},
#                                             <heap.MinHeap at 0x7fba585e96d8>]},
#                                           <heap.MinHeap at 0x7fba585e9470>]},
#                                         <heap.MinHeap at 0x7fba5b2efa20>]},
#                                       <heap.MinHeap at 0x7fba5b2ef860>]},
#                                     <heap.MinHeap at 0x7fba5b2ef400>]},
#                                   <heap.MinHeap at 0x7fba5b2effd0>]},
#                                 <heap.MinHeap at 0x7fba5b2ef5c0>]},
#                               <heap.MinHeap at 0x7fba5b2efeb8>]},
#                             <heap.MinHeap at 0x7fba5b72da90>]},
#                           <heap.MinHeap at 0x7fba5b72dd30>]},
#                         <heap.MinHeap at 0x7fba5b72df28>]},
#                       <heap.MinHeap at 0x7fba5b72da20>]},
#                     <heap.MinHeap at 0x7fba5b72d240>]},
#                   <heap.MinHeap at 0x7fba5b72d978>]},
#                 <heap.MinHeap at 0x7fba53d73358>]},
#               <heap.MinHeap at 0x7fba53d73048>]},
#             <heap.MinHeap at 0x7fba53d73320>],
#            'и': [{'е': [{' ': [{'о': [{'з': [{'ё': [{'р': [{'а': [{},
#                           <heap.MinHeap at 0x7fba58c2cdd8>,
#                           None]},
#                         <heap.MinHeap at 0x7fba58c2cef0>]},
#                       <heap.MinHeap at 0x7fba58c2c6a0>]},
#                     <heap.MinHeap at 0x7fba58c2cd68>]},
#                   <heap.MinHeap at 0x7fba58c2ce80>]},
#                 <heap.MinHeap at 0x7fba58c2c518>]},
#               <heap.MinHeap at 0x7fba58c2ceb8>]},
#             <heap.MinHeap at 0x7fba58c2c908>]},
#           <heap.MinHeap at 0x7fba53d73978>]},
#         <heap.MinHeap at 0x7fba53d738d0>]},
#       <heap.MinHeap at 0x7fba53d73d68>]},
#     <heap.MinHeap at 0x7fba53d73588>],
#    'о': [{'д': [{'о': [{'п': [{'а': [{'д': [{' ': [{'В': [{'и': [{'к': [{'т': [{'о': [{'р': [{'и': [{'я': [{},
#                                 <heap.MinHeap at 0x7fba5eda6b70>,
#                                 None]},
#                               <heap.MinHeap at 0x7fba5eda6eb8>]},
#                             <heap.MinHeap at 0x7fba58851da0>]},
#                           <heap.MinHeap at 0x7fba583c1898>]},
#                         <heap.MinHeap at 0x7fba583c1390>]},
#                       <heap.MinHeap at 0x7fba583c1a58>]},
#                     <heap.MinHeap at 0x7fba59929358>]},
#                   <heap.MinHeap at 0x7fba599294a8>]},
#                 <heap.MinHeap at 0x7fba59929da0>]},
#               <heap.MinHeap at 0x7fba599296d8>]},
#             <heap.MinHeap at 0x7fba59929e48>]},
#           <heap.MinHeap at 0x7fba59929b00>]},
#         <heap.MinHeap at 0x7fba599299e8>]},
#       <heap.MinHeap at 0x7fba59929ef0>],
#      'р': [{'о': [{'б': [{'ь': [{'е': [{'в': [{'ы': [{' ': [{'г': [{'о': [{'р': [{'ы': [{},
#                             <heap.MinHeap at 0x7fba5a2f0898>,
#                             None]},
#                           <heap.MinHeap at 0x7fba5a2f0f60>]},
#                         <heap.MinHeap at 0x7fba5a2f0f28>]},
#                       <heap.MinHeap at 0x7fba585d9a58>]},
#                     <heap.MinHeap at 0x7fba585d9780>]},
#                   <heap.MinHeap at 0x7fba585d9278>]},
#                 <heap.MinHeap at 0x7fba585d9f60>]},
#               <heap.MinHeap at 0x7fba585d9e10>]},
#             <heap.MinHeap at 0x7fba636f16d8>]},
#           <heap.MinHeap at 0x7fba636f17f0>]},
#         <heap.MinHeap at 0x7fba636f1940>]},
#       <heap.MinHeap at 0x7fba636f1550>]},
#     <heap.MinHeap at 0x7fba59929d30>]},
#   <heap.MinHeap at 0x7fba53d73a58>],
#  'Г': [{'а': [{'в': [{'а': [{'й': [{'с': [{'к': [{'и': [{'е': [{' ': [{'о': [{'с': [{'т': [{'р': [{'о': [{'в': [{'а': [{},
#                                   <heap.MinHeap at 0x7fba64e78f98>,
#                                   None]},
#                                 <heap.MinHeap at 0x7fba64e780b8>]},
#                               <heap.MinHeap at 0x7fba5b5d8a90>]},
#                             <heap.MinHeap at 0x7fba5b5d8cc0>]},
#                           <heap.MinHeap at 0x7fba5444ff60>]},
#                         <heap.MinHeap at 0x7fba5444f0b8>]},
#                       <heap.MinHeap at 0x7fba5444f780>]},
#                     <heap.MinHeap at 0x7fba5444f748>]},
#                   <heap.MinHeap at 0x7fba5444f208>]},
#                 <heap.MinHeap at 0x7fba5444f630>]},
#               <heap.MinHeap at 0x7fba5444f908>]},
#             <heap.MinHeap at 0x7fba52ef51d0>]},
#           <heap.MinHeap at 0x7fba583062b0>]},
#         <heap.MinHeap at 0x7fba58306a90>]},
#       <heap.MinHeap at 0x7fba5968c2b0>]},
#     <heap.MinHeap at 0x7fba5968ccc0>],
#    'о': [{'а': [{}, <heap.MinHeap at 0x7fba66197d68>, None],
#      'л': [{'л': [{'и': [{'в': [{'у': [{'д': [{},
#                 <heap.MinHeap at 0x7fba5a2a6ba8>,
#                 None]},
#               <heap.MinHeap at 0x7fba5a2a6908>]},
#             <heap.MinHeap at 0x7fba5a2a67b8>]},
#           <heap.MinHeap at 0x7fba584cef28>]},
#         <heap.MinHeap at 0x7fba584ce0f0>]},
#       <heap.MinHeap at 0x7fba584ced30>]},
#     <heap.MinHeap at 0x7fba584cecc0>],
#    'р': [{'а': [{'н': [{'д': [{'-': [{'К': [{'а': [{'н': [{'ь': [{'о': [{'н': [{},
#                         <heap.MinHeap at 0x7fba584e4860>,
#                         None]},
#                       <heap.MinHeap at 0x7fba584e4550>]},
#                     <heap.MinHeap at 0x7fba584e4668>]},
#                   <heap.MinHeap at 0x7fba59be6a20>]},
#                 <heap.MinHeap at 0x7fba59be66a0>]},
#               <heap.MinHeap at 0x7fba59be6400>]},
#             <heap.MinHeap at 0x7fba59be6160>]},
#           <heap.MinHeap at 0x7fba64e78128>]},
#         <heap.MinHeap at 0x7fba64e78e48>]},
#       <heap.MinHeap at 0x7fba64e78dd8>],
#      'е': [{'н': [{'л': [{'а': [{'н': [{'д': [{'и': [{'я': [{},
#                     <heap.MinHeap at 0x7fba58c36ef0>,
#                     None]},
#                   <heap.MinHeap at 0x7fba58c36668>]},
#                 <heap.MinHeap at 0x7fba58c36eb8>]},
#               <heap.MinHeap at 0x7fba58c362b0>]},
#             <heap.MinHeap at 0x7fba58c36dd8>]},
#           <heap.MinHeap at 0x7fba58c36160>]},
#         <heap.MinHeap at 0x7fba58c366d8>]},
#       <heap.MinHeap at 0x7fba58c361d0>]},
#     <heap.MinHeap at 0x7fba585e9cc0>]},
#   <heap.MinHeap at 0x7fba584ce9b0>],
#  'Д': [{'в': [{'о': [{'р': [{'ц': [{'о': [{'в': [{'о': [{'-': [{'п': [{'а': [{'р': [{'к': [{'о': [{'в': [{'ы': [{'й': [{' ': [{'а': [{'н': [{'с': [{'а': [{'м': [{'б': [{'л': [{'ь': [{' ': [{'П': [{'е': [{'т': [{'е': [{'р': [{'г': [{'о': [{'ф': [{},
#                                                                       <heap.MinHeap at 0x7fba5b7875c0>,
#                                                                       None]},
#                                                                     <heap.MinHeap at 0x7fba5b787438>]},
#                                                                   <heap.MinHeap at 0x7fba5a4efa58>]},
#                                                                 <heap.MinHeap at 0x7fba5a4efb70>]},
#                                                               <heap.MinHeap at 0x7fba5a4ef6d8>]},
#                                                             <heap.MinHeap at 0x7fba5a4ef080>]},
#                                                           <heap.MinHeap at 0x7fba5b5c4358>]},
#                                                         <heap.MinHeap at 0x7fba5b5c4d68>]},
#                                                       <heap.MinHeap at 0x7fba5b5c4ba8>]},
#                                                     <heap.MinHeap at 0x7fba5b5c4828>]},
#                                                   <heap.MinHeap at 0x7fba5b5c49e8>]},
#                                                 <heap.MinHeap at 0x7fba5b5c4748>]},
#                                               <heap.MinHeap at 0x7fba5b8f44e0>]},
#                                             <heap.MinHeap at 0x7fba5b8f4048>]},
#                                           <heap.MinHeap at 0x7fba5b8f4f98>]},
#                                         <heap.MinHeap at 0x7fba5b8f4c50>]},
#                                       <heap.MinHeap at 0x7fba5b8f4898>]},
#                                     <heap.MinHeap at 0x7fba5b8f46d8>]},
#                                   <heap.MinHeap at 0x7fba5b8f4518>]},
#                                 <heap.MinHeap at 0x7fba5442a8d0>]},
#                               <heap.MinHeap at 0x7fba5442add8>]},
#                             <heap.MinHeap at 0x7fba6618ea58>]},
#                           <heap.MinHeap at 0x7fba6618e6d8>]},
#                         <heap.MinHeap at 0x7fba6618eac8>]},
#                       <heap.MinHeap at 0x7fba6618e0f0>]},
#                     <heap.MinHeap at 0x7fba6618ecf8>]},
#                   <heap.MinHeap at 0x7fba6618e2b0>]},
#                 <heap.MinHeap at 0x7fba6618eb70>]},
#               <heap.MinHeap at 0x7fba5bde8b70>]},
#             <heap.MinHeap at 0x7fba5bde8898>]},
#           <heap.MinHeap at 0x7fba5bde8400>]},
#         <heap.MinHeap at 0x7fba5bde8c18>]},
#       <heap.MinHeap at 0x7fba5bde8978>]},
#     <heap.MinHeap at 0x7fba5bde8e10>],
#    'и': [{'с': [{'н': [{'е': [{'й': [{'л': [{'е': [{'н': [{'д': [{' ': [{'в': [{' ': [{'П': [{'а': [{'р': [{'и': [{'ж': [{'е': [{},
#                                       <heap.MinHeap at 0x7fba638f7748>,
#                                       None]},
#                                     <heap.MinHeap at 0x7fba638f78d0>]},
#                                   <heap.MinHeap at 0x7fba5b384978>]},
#                                 <heap.MinHeap at 0x7fba5b384828>]},
#                               <heap.MinHeap at 0x7fba5b3846a0>]},
#                             <heap.MinHeap at 0x7fba5b3842b0>]},
#                           <heap.MinHeap at 0x7fba5b384eb8>]},
#                         <heap.MinHeap at 0x7fba584ebc18>]},
#                       <heap.MinHeap at 0x7fba584eb898>]},
#                     <heap.MinHeap at 0x7fba584eb5f8>]},
#                   <heap.MinHeap at 0x7fba584eb358>]},
#                 <heap.MinHeap at 0x7fba584eb0b8>]},
#               <heap.MinHeap at 0x7fba584eb198>]},
#             <heap.MinHeap at 0x7fba5b787128>]},
#           <heap.MinHeap at 0x7fba5b787ba8>]},
#         <heap.MinHeap at 0x7fba5b787748>]},
#       <heap.MinHeap at 0x7fba5b7874e0>]},
#     <heap.MinHeap at 0x7fba5b7873c8>],
#    'о': [{'л': [{'и': [{'н': [{'а': [{' ': [{'С': [{'м': [{'е': [{'р': [{'т': [{'и': [{},
#                           <heap.MinHeap at 0x7fba636d4128>,
#                           None]},
#                         <heap.MinHeap at 0x7fba636d4f98>]},
#                       <heap.MinHeap at 0x7fba636d48d0>]},
#                     <heap.MinHeap at 0x7fba5cfb8ef0>]},
#                   <heap.MinHeap at 0x7fba5cfb86d8>]},
#                 <heap.MinHeap at 0x7fba5cfb8080>]},
#               <heap.MinHeap at 0x7fba5cfb8f60>]},
#             <heap.MinHeap at 0x7fba5cfb8748>]},
#           <heap.MinHeap at 0x7fba5cfb85f8>]},
#         <heap.MinHeap at 0x7fba584e4780>]},
#       <heap.MinHeap at 0x7fba584e43c8>]},
#     <heap.MinHeap at 0x7fba584e4ef0>]},
#   <heap.MinHeap at 0x7fba5cebb240>],
#  'Е': [{'г': [{'и': [{'п': [{'е': [{'т': [{'с': [{'к': [{'и': [{'е': [{' ': [{'п': [{'и': [{'р': [{'а': [{'м': [{'и': [{'д': [{'ы': [{},
#                                       <heap.MinHeap at 0x7fba5a107780>,
#                                       None]},
#                                     <heap.MinHeap at 0x7fba5a107eb8>]},
#                                   <heap.MinHeap at 0x7fba5a107f28>]},
#                                 <heap.MinHeap at 0x7fba6767a828>]},
#                               <heap.MinHeap at 0x7fba6767aba8>]},
#                             <heap.MinHeap at 0x7fba6767a2e8>]},
#                           <heap.MinHeap at 0x7fba6767a1d0>]},
#                         <heap.MinHeap at 0x7fba5efd1438>]},
#                       <heap.MinHeap at 0x7fba5efd17b8>]},
#                     <heap.MinHeap at 0x7fba5efd1080>]},
#                   <heap.MinHeap at 0x7fba5efd1b38>]},
#                 <heap.MinHeap at 0x7fba5872dc18>]},
#               <heap.MinHeap at 0x7fba64485be0>]},
#             <heap.MinHeap at 0x7fba583d87f0>]},
#           <heap.MinHeap at 0x7fba583d80b8>]},
#         <heap.MinHeap at 0x7fba583d8f98>]},
#       <heap.MinHeap at 0x7fba583d8eb8>]},
#     <heap.MinHeap at 0x7fba59631358>],
#    'л': [{'и': [{'с': [{'е': [{'й': [{'с': [{'к': [{'и': [{'е': [{' ': [{'п': [{'о': [{'л': [{'я': [{},
#                               <heap.MinHeap at 0x7fba5bd2d2e8>,
#                               None]},
#                             <heap.MinHeap at 0x7fba5b9b6c18>]},
#                           <heap.MinHeap at 0x7fba5b9b6cf8>]},
#                         <heap.MinHeap at 0x7fba5b9b6c88>]},
#                       <heap.MinHeap at 0x7fba585e1588>]},
#                     <heap.MinHeap at 0x7fba585e1ac8>]},
#                   <heap.MinHeap at 0x7fba585e18d0>]},
#                 <heap.MinHeap at 0x7fba585e1390>]},
#               <heap.MinHeap at 0x7fba585e1e48>]},
#             <heap.MinHeap at 0x7fba585e1d68>]},
#           <heap.MinHeap at 0x7fba5a10cf60>]},
#         <heap.MinHeap at 0x7fba5a10c240>]},
#       <heap.MinHeap at 0x7fba636d4d68>]},
#     <heap.MinHeap at 0x7fba636d4588>]},
#   <heap.MinHeap at 0x7fba59631160>],
#  'З': [{'а': [{'м': [{'о': [{'к': [{' ': [{'Н': [{'о': [{'й': [{'ш': [{'в': [{'а': [{'н': [{'ш': [{'т': [{'а': [{'й': [{'н': [{},
#                                     <heap.MinHeap at 0x7fba5b707278>,
#                                     None]},
#                                   <heap.MinHeap at 0x7fba5b707fd0>]},
#                                 <heap.MinHeap at 0x7fba5b707e80>]},
#                               <heap.MinHeap at 0x7fba5b707ef0>]},
#                             <heap.MinHeap at 0x7fba5a117278>]},
#                           <heap.MinHeap at 0x7fba5a1179b0>]},
#                         <heap.MinHeap at 0x7fba5a117f98>]},
#                       <heap.MinHeap at 0x7fba5a117358>]},
#                     <heap.MinHeap at 0x7fba5a38f278>]},
#                   <heap.MinHeap at 0x7fba5a136390>]},
#                 <heap.MinHeap at 0x7fba5a136c50>]},
#               <heap.MinHeap at 0x7fba5e64a2e8>]},
#             <heap.MinHeap at 0x7fba5e64a4e0>]},
#           <heap.MinHeap at 0x7fba5e64a550>]},
#         <heap.MinHeap at 0x7fba5e646080>]},
#       <heap.MinHeap at 0x7fba5e646828>],
#      'н': [{'з': [{'и': [{'б': [{'а': [{'р': [{},
#                 <heap.MinHeap at 0x7fba53c88400>,
#                 None]},
#               <heap.MinHeap at 0x7fba53c88048>]},
#             <heap.MinHeap at 0x7fba53c888d0>]},
#           <heap.MinHeap at 0x7fba53c88fd0>]},
#         <heap.MinHeap at 0x7fba53c88b00>]},
#       <heap.MinHeap at 0x7fba53c88da0>]},
#     <heap.MinHeap at 0x7fba53c887f0>],
#    'и': [{'м': [{'н': [{'и': [{'й': [{' ': [{'д': [{'в': [{'о': [{'р': [{'е': [{'ц': [{},
#                           <heap.MinHeap at 0x7fba5dd4e668>,
#                           None]},
#                         <heap.MinHeap at 0x7fba5dd4e208>]},
#                       <heap.MinHeap at 0x7fba5b5c1358>]},
#                     <heap.MinHeap at 0x7fba5b5c14a8>]},
#                   <heap.MinHeap at 0x7fba5b5c1ef0>]},
#                 <heap.MinHeap at 0x7fba5b5c19e8>]},
#               <heap.MinHeap at 0x7fba5b5c19b0>]},
#             <heap.MinHeap at 0x7fba585f46d8>]},
#           <heap.MinHeap at 0x7fba585f4b00>]},
#         <heap.MinHeap at 0x7fba585f4a90>]},
#       <heap.MinHeap at 0x7fba5a2f0c50>]},
#     <heap.MinHeap at 0x7fba5a2f05f8>]},
#   <heap.MinHeap at 0x7fba5a2eb630>],
#  'И': [{'з': [{'м': [{'а': [{'й': [{'л': [{'о': [{'в': [{'с': [{'к': [{'и': [{'й': [{' ': [{'п': [{'а': [{'р': [{'к': [{},
#                                   <heap.MinHeap at 0x7fba5a45d4e0>,
#                                   None]},
#                                 <heap.MinHeap at 0x7fba5be872b0>]},
#                               <heap.MinHeap at 0x7fba5be87898>]},
#                             <heap.MinHeap at 0x7fba5be87588>]},
#                           <heap.MinHeap at 0x7fba5be874a8>]},
#                         <heap.MinHeap at 0x7fba5be877b8>]},
#                       <heap.MinHeap at 0x7fba5be87ba8>]},
#                     <heap.MinHeap at 0x7fba596210b8>]},
#                   <heap.MinHeap at 0x7fba59621748>]},
#                 <heap.MinHeap at 0x7fba5b3da860>]},
#               <heap.MinHeap at 0x7fba5b3da320>]},
#             <heap.MinHeap at 0x7fba5b3dac18>]},
#           <heap.MinHeap at 0x7fba5b3daba8>]},
#         <heap.MinHeap at 0x7fba5dd4ec88>]},
#       <heap.MinHeap at 0x7fba5dd4e400>]},
#     <heap.MinHeap at 0x7fba5dd4e588>],
#    'с': [{'с': [{'ы': [{'к': [{'-': [{'к': [{'у': [{'л': [{'ь': [{},
#                     <heap.MinHeap at 0x7fba64e19a20>,
#                     None]},
#                   <heap.MinHeap at 0x7fba64e19160>]},
#                 <heap.MinHeap at 0x7fba64e191d0>]},
#               <heap.MinHeap at 0x7fba64e19c50>]},
#             <heap.MinHeap at 0x7fba64e197f0>]},
#           <heap.MinHeap at 0x7fba6529e5c0>]},
#         <heap.MinHeap at 0x7fba6529e7f0>]},
#       <heap.MinHeap at 0x7fba6529ebe0>]},
#     <heap.MinHeap at 0x7fba6529e6a0>]},
#   <heap.MinHeap at 0x7fba5dd4e550>],
#  'Й': [{'о': [{'з': [{'е': [{'ф': [{'о': [{'в': [{},
#               <heap.MinHeap at 0x7fba53ca7b38>,
#               None]},
#             <heap.MinHeap at 0x7fba53ca2710>]},
#           <heap.MinHeap at 0x7fba53ca2550>]},
#         <heap.MinHeap at 0x7fba53ca2b70>]},
#       <heap.MinHeap at 0x7fba53ca2d30>]},
#     <heap.MinHeap at 0x7fba53ca2438>]},
#   <heap.MinHeap at 0x7fba53ca2390>],
#  'К': [{'а': [{'н': [{'а': [{'р': [{'с': [{'к': [{'и': [{'е': [{' ': [{'о': [{'с': [{'т': [{'р': [{'о': [{'в': [{'а': [{},
#                                   <heap.MinHeap at 0x7fba58bea160>,
#                                   None]},
#                                 <heap.MinHeap at 0x7fba59bf13c8>]},
#                               <heap.MinHeap at 0x7fba59bf1d68>]},
#                             <heap.MinHeap at 0x7fba59bf1ac8>]},
#                           <heap.MinHeap at 0x7fba59bf17f0>]},
#                         <heap.MinHeap at 0x7fba59bf1208>]},
#                       <heap.MinHeap at 0x7fba59bf12b0>]},
#                     <heap.MinHeap at 0x7fba5b504a90>]},
#                   <heap.MinHeap at 0x7fba5b5049b0>]},
#                 <heap.MinHeap at 0x7fba5b5040b8>]},
#               <heap.MinHeap at 0x7fba5b504400>]},
#             <heap.MinHeap at 0x7fba5b5047b8>]},
#           <heap.MinHeap at 0x7fba5b504710>]},
#         <heap.MinHeap at 0x7fba5a2a6208>]},
#       <heap.MinHeap at 0x7fba5a2a64a8>],
#      'п': [{'п': [{'а': [{'д': [{'о': [{'к': [{'и': [{'я': [{},
#                     <heap.MinHeap at 0x7fba5a4e9240>,
#                     None]},
#                   <heap.MinHeap at 0x7fba5a4e97f0>]},
#                 <heap.MinHeap at 0x7fba5a4e9a20>]},
#               <heap.MinHeap at 0x7fba5a4e9ef0>]},
#             <heap.MinHeap at 0x7fba5a4e9f28>]},
#           <heap.MinHeap at 0x7fba5a4e9978>]},
#         <heap.MinHeap at 0x7fba585dce10>]},
#       <heap.MinHeap at 0x7fba585dccc0>],
#      'р': [{'л': [{'о': [{'в': [{' ': [{'м': [{'о': [{'с': [{'т': [{},
#                       <heap.MinHeap at 0x7fba636cfeb8>,
#                       None]},
#                     <heap.MinHeap at 0x7fba636cf2e8>]},
#                   <heap.MinHeap at 0x7fba636cff60>]},
#                 <heap.MinHeap at 0x7fba636cf8d0>]},
#               <heap.MinHeap at 0x7fba636cfe10>]},
#             <heap.MinHeap at 0x7fba5940d160>]},
#           <heap.MinHeap at 0x7fba5940d3c8>]},
#         <heap.MinHeap at 0x7fba5940d7f0>]},
#       <heap.MinHeap at 0x7fba5940d898>]},
#     <heap.MinHeap at 0x7fba5a2a6a90>],
#    'о': [{'л': [{'и': [{'з': [{'е': [{'й': [{},
#               <heap.MinHeap at 0x7fba638e5e80>,
#               None]},
#             <heap.MinHeap at 0x7fba638e5710>]},
#           <heap.MinHeap at 0x7fba638e5908>]},
#         <heap.MinHeap at 0x7fba638e5518>]},
#       <heap.MinHeap at 0x7fba638e5c18>]},
#     <heap.MinHeap at 0x7fba59720be0>],
#    'р': [{'а': [{'с': [{'н': [{'а': [{'я': [{' ': [{'п': [{'л': [{'о': [{'щ': [{'а': [{'д': [{'ь': [{},
#                               <heap.MinHeap at 0x7fba5b3eb550>,
#                               None]},
#                             <heap.MinHeap at 0x7fba5a5a69e8>]},
#                           <heap.MinHeap at 0x7fba5a5a63c8>]},
#                         <heap.MinHeap at 0x7fba5a5a6e48>]},
#                       <heap.MinHeap at 0x7fba5a5a6a58>]},
#                     <heap.MinHeap at 0x7fba5a5a6ef0>]},
#                   <heap.MinHeap at 0x7fba59bd93c8>]},
#                 <heap.MinHeap at 0x7fba59bd9a58>]},
#               <heap.MinHeap at 0x7fba59bd9198>]},
#             <heap.MinHeap at 0x7fba59bd9978>]},
#           <heap.MinHeap at 0x7fba595d3c50>]},
#         <heap.MinHeap at 0x7fba595d37f0>]},
#       <heap.MinHeap at 0x7fba595d32b0>]},
#     <heap.MinHeap at 0x7fba595d3fd0>]},
#   <heap.MinHeap at 0x7fba597207f0>],
#  'Л': [{'а': [{'з': [{'у': [{'р': [{'н': [{'ы': [{'й': [{' ': [{'б': [{'е': [{'р': [{'е': [{'г': [{},
#                             <heap.MinHeap at 0x7fba5b396748>,
#                             None]},
#                           <heap.MinHeap at 0x7fba5b3967f0>]},
#                         <heap.MinHeap at 0x7fba5b396198>]},
#                       <heap.MinHeap at 0x7fba5b396c18>]},
#                     <heap.MinHeap at 0x7fba5b396f28>]},
#                   <heap.MinHeap at 0x7fba5c3ed978>]},
#                 <heap.MinHeap at 0x7fba5c3edac8>]},
#               <heap.MinHeap at 0x7fba5c3ed710>]},
#             <heap.MinHeap at 0x7fba5c3ed2e8>]},
#           <heap.MinHeap at 0x7fba5c3ede80>]},
#         <heap.MinHeap at 0x7fba5c3edc88>]},
#       <heap.MinHeap at 0x7fba5a1086d8>]},
#     <heap.MinHeap at 0x7fba5a108128>],
#    'у': [{'в': [{'р': [{}, <heap.MinHeap at 0x7fba638f75f8>, None]},
#       <heap.MinHeap at 0x7fba638f7b38>]},
#     <heap.MinHeap at 0x7fba638f7630>]},
#   <heap.MinHeap at 0x7fba638f7e10>],
#  'М': [{'а': [{'л': [{'а': [{' ': [{'С': [{'т': [{'р': [{'а': [{'н': [{'а': [{},
#                       <heap.MinHeap at 0x7fba5bd99518>,
#                       None]},
#                     <heap.MinHeap at 0x7fba5bd995c0>]},
#                   <heap.MinHeap at 0x7fba5bd99240>]},
#                 <heap.MinHeap at 0x7fba5911c080>]},
#               <heap.MinHeap at 0x7fba58c367f0>]},
#             <heap.MinHeap at 0x7fba58c368d0>]},
#           <heap.MinHeap at 0x7fba58c36b00>]},
#         <heap.MinHeap at 0x7fba58c36438>]},
#       <heap.MinHeap at 0x7fba58c36390>],
#      'н': [{'х': [{'э': [{'т': [{'т': [{'е': [{'н': [{},
#                   <heap.MinHeap at 0x7fba585f8080>,
#                   None]},
#                 <heap.MinHeap at 0x7fba585f86d8>]},
#               <heap.MinHeap at 0x7fba585f8400>]},
#             <heap.MinHeap at 0x7fba58bea5c0>]},
#           <heap.MinHeap at 0x7fba58bea4a8>]},
#         <heap.MinHeap at 0x7fba58bea8d0>]},
#       <heap.MinHeap at 0x7fba58bea908>],
#      'р': [{'и': [{'а': [{'н': [{'с': [{'к': [{'а': [{'я': [{' ': [{'в': [{'п': [{'а': [{'д': [{'и': [{'н': [{'а': [{},
#                                     <heap.MinHeap at 0x7fba54409128>,
#                                     None]},
#                                   <heap.MinHeap at 0x7fba54409ba8>]},
#                                 <heap.MinHeap at 0x7fba5b5e8da0>]},
#                               <heap.MinHeap at 0x7fba5b5e86d8>]},
#                             <heap.MinHeap at 0x7fba5b5e8c50>]},
#                           <heap.MinHeap at 0x7fba5b5e8630>]},
#                         <heap.MinHeap at 0x7fba5b5e8470>]},
#                       <heap.MinHeap at 0x7fba5b5e80f0>]},
#                     <heap.MinHeap at 0x7fba5b5e8ef0>]},
#                   <heap.MinHeap at 0x7fba5ed8f2b0>]},
#                 <heap.MinHeap at 0x7fba5ed8f0b8>]},
#               <heap.MinHeap at 0x7fba5ed8ff98>]},
#             <heap.MinHeap at 0x7fba5ed8fba8>]},
#           <heap.MinHeap at 0x7fba5ed8f518>]},
#         <heap.MinHeap at 0x7fba5ed8f7f0>],
#        'ф': [{'о': [{'-': [{'М': [{'а': [{'р': [{'и': [{'и': [{'н': [{'с': [{'к': [{'а': [{'я': [{' ': [{'о': [{'б': [{'и': [{'т': [{'е': [{'л': [{'ь': [{},
#                                                 <heap.MinHeap at 0x7fba5b39fa90>,
#                                                 None]},
#                                               <heap.MinHeap at 0x7fba5b39f5c0>]},
#                                             <heap.MinHeap at 0x7fba5b39f278>]},
#                                           <heap.MinHeap at 0x7fba5b39fb70>]},
#                                         <heap.MinHeap at 0x7fba5b39fda0>]},
#                                       <heap.MinHeap at 0x7fba5990db00>]},
#                                     <heap.MinHeap at 0x7fba5990d470>]},
#                                   <heap.MinHeap at 0x7fba5990d7f0>]},
#                                 <heap.MinHeap at 0x7fba5990d438>]},
#                               <heap.MinHeap at 0x7fba5990d320>]},
#                             <heap.MinHeap at 0x7fba5990d278>]},
#                           <heap.MinHeap at 0x7fba5990de80>]},
#                         <heap.MinHeap at 0x7fba5990d9e8>]},
#                       <heap.MinHeap at 0x7fba5990ddd8>]},
#                     <heap.MinHeap at 0x7fba5990d390>]},
#                   <heap.MinHeap at 0x7fba5a4f8e10>]},
#                 <heap.MinHeap at 0x7fba5a4f80f0>]},
#               <heap.MinHeap at 0x7fba5a4f8c88>]},
#             <heap.MinHeap at 0x7fba5a4f8898>]},
#           <heap.MinHeap at 0x7fba5a4f8c50>]},
#         <heap.MinHeap at 0x7fba5a4f8cc0>]},
#       <heap.MinHeap at 0x7fba5ed8f278>],
#      'ч': [{'у': [{'-': [{'П': [{'и': [{'к': [{'ч': [{'у': [{},
#                     <heap.MinHeap at 0x7fba583c4d30>,
#                     None]},
#                   <heap.MinHeap at 0x7fba5ce43828>]},
#                 <heap.MinHeap at 0x7fba5ce43278>]},
#               <heap.MinHeap at 0x7fba5ce43630>]},
#             <heap.MinHeap at 0x7fba5ce43978>]},
#           <heap.MinHeap at 0x7fba5ce43518>]},
#         <heap.MinHeap at 0x7fba66197b00>]},
#       <heap.MinHeap at 0x7fba66197080>]},
#     <heap.MinHeap at 0x7fba58bea3c8>],
#    'е': [{'р': [{'т': [{'в': [{'о': [{'е': [{' ': [{'м': [{'о': [{'р': [{'е': [{},
#                         <heap.MinHeap at 0x7fba5b3f0860>,
#                         None]},
#                       <heap.MinHeap at 0x7fba5b3f0470>]},
#                     <heap.MinHeap at 0x7fba5b953b70>]},
#                   <heap.MinHeap at 0x7fba5b953898>]},
#                 <heap.MinHeap at 0x7fba5b953ef0>]},
#               <heap.MinHeap at 0x7fba5b3ebc18>]},
#             <heap.MinHeap at 0x7fba5b3ebb00>]},
#           <heap.MinHeap at 0x7fba5b3eba20>]},
#         <heap.MinHeap at 0x7fba5b3eba90>]},
#       <heap.MinHeap at 0x7fba5b3eb8d0>]},
#     <heap.MinHeap at 0x7fba5b3eb198>],
#    'о': [{'с': [{'к': [{'в': [{'а': [{'-': [{'р': [{'е': [{'к': [{'а': [{},
#                       <heap.MinHeap at 0x7fba54efd828>,
#                       None]},
#                     <heap.MinHeap at 0x7fba54efda20>]},
#                   <heap.MinHeap at 0x7fba54efda90>]},
#                 <heap.MinHeap at 0x7fba53c84be0>]},
#               <heap.MinHeap at 0x7fba53c84cf8>]},
#             <heap.MinHeap at 0x7fba53c84f28>]},
#           <heap.MinHeap at 0x7fba53d7bb38>],
#          'о': [{'в': [{'с': [{'к': [{'и': [{'й': [{' ': [{'К': [{'р': [{'е': [{'м': [{'л': [{'ь': [{},
#                                   <heap.MinHeap at 0x7fba5b7b2588>,
#                                   None]},
#                                 <heap.MinHeap at 0x7fba5b7b29e8>]},
#                               <heap.MinHeap at 0x7fba5b7b20b8>]},
#                             <heap.MinHeap at 0x7fba5b7b2e10>]},
#                           <heap.MinHeap at 0x7fba5b7b2518>]},
#                         <heap.MinHeap at 0x7fba5b7b24e0>],
#                        'г': [{'о': [{'с': [{'у': [{'д': [{'а': [{'р': [{'с': [{'т': [{'в': [{'е': [{'н': [{'н': [{'ы': [{'й': [{' ': [{'у': [{'н': [{'и': [{'в': [{'е': [{'р': [{'с': [{'и': [{'т': [{'е': [{'т': [{' ': [{'и': [{'м': [{'е': [{'н': [{'и': [{' ': [{'М': [{'.': [{'В': [{'.': [{' ': [{'Л': [{'о': [{'м': [{'о': [{'н': [{'о': [{'с': [{'о': [{'в': [{'а': [{' ': [{'(': [{'М': [{'Г': [{'У': [{')': [{},
#                                                                                                                                     <heap.MinHeap at 0x7fba64e6c0f0>,
#                                                                                                                                     None]},
#                                                                                                                                   <heap.MinHeap at 0x7fba64e6c908>]},
#                                                                                                                                 <heap.MinHeap at 0x7fba64e6cf98>]},
#                                                                                                                               <heap.MinHeap at 0x7fba583e0860>]},
#                                                                                                                             <heap.MinHeap at 0x7fba583e0128>]},
#                                                                                                                           <heap.MinHeap at 0x7fba583e0940>]},
#                                                                                                                         <heap.MinHeap at 0x7fba583e0ef0>]},
#                                                                                                                       <heap.MinHeap at 0x7fba5972f438>]},
#                                                                                                                     <heap.MinHeap at 0x7fba5972ff98>]},
#                                                                                                                   <heap.MinHeap at 0x7fba5972ff28>]},
#                                                                                                                 <heap.MinHeap at 0x7fba5972f780>]},
#                                                                                                               <heap.MinHeap at 0x7fba58a658d0>]},
#                                                                                                             <heap.MinHeap at 0x7fba58a65cc0>]},
#                                                                                                           <heap.MinHeap at 0x7fba58a659e8>]},
#                                                                                                         <heap.MinHeap at 0x7fba58a655f8>]},
#                                                                                                       <heap.MinHeap at 0x7fba58a65438>]},
#                                                                                                     <heap.MinHeap at 0x7fba58a65390>]},
#                                                                                                   <heap.MinHeap at 0x7fba58a65358>]},
#                                                                                                 <heap.MinHeap at 0x7fba58a65198>]},
#                                                                                               <heap.MinHeap at 0x7fba58a65dd8>]},
#                                                                                             <heap.MinHeap at 0x7fba58a65eb8>]},
#                                                                                           <heap.MinHeap at 0x7fba5a154588>]},
#                                                                                         <heap.MinHeap at 0x7fba5a154358>]},
#                                                                                       <heap.MinHeap at 0x7fba5a154940>]},
#                                                                                     <heap.MinHeap at 0x7fba5a154748>]},
#                                                                                   <heap.MinHeap at 0x7fba5b5ec390>]},
#                                                                                 <heap.MinHeap at 0x7fba5b5ec198>]},
#                                                                               <heap.MinHeap at 0x7fba5b5ecda0>]},
#                                                                             <heap.MinHeap at 0x7fba5b5ecd68>]},
#                                                                           <heap.MinHeap at 0x7fba5b5ec828>]},
#                                                                         <heap.MinHeap at 0x7fba5b738710>]},
#                                                                       <heap.MinHeap at 0x7fba5b738400>]},
#                                                                     <heap.MinHeap at 0x7fba5b738208>]},
#                                                                   <heap.MinHeap at 0x7fba5b738eb8>]},
#                                                                 <heap.MinHeap at 0x7fba5b738da0>]},
#                                                               <heap.MinHeap at 0x7fba5b738c88>]},
#                                                             <heap.MinHeap at 0x7fba5b738c50>]},
#                                                           <heap.MinHeap at 0x7fba5b738940>]},
#                                                         <heap.MinHeap at 0x7fba5e3177b8>]},
#                                                       <heap.MinHeap at 0x7fba5e317eb8>]},
#                                                     <heap.MinHeap at 0x7fba5e317780>]},
#                                                   <heap.MinHeap at 0x7fba5e3176d8>]},
#                                                 <heap.MinHeap at 0x7fba5e317390>]},
#                                               <heap.MinHeap at 0x7fba5e317f60>]},
#                                             <heap.MinHeap at 0x7fba5e317550>]},
#                                           <heap.MinHeap at 0x7fba5e317a90>]},
#                                         <heap.MinHeap at 0x7fba5e317da0>]},
#                                       <heap.MinHeap at 0x7fba676804a8>]},
#                                     <heap.MinHeap at 0x7fba67680358>]},
#                                   <heap.MinHeap at 0x7fba67680630>]},
#                                 <heap.MinHeap at 0x7fba67680550>]},
#                               <heap.MinHeap at 0x7fba67680c18>]},
#                             <heap.MinHeap at 0x7fba5b2ead68>]},
#                           <heap.MinHeap at 0x7fba5b2eac50>]},
#                         <heap.MinHeap at 0x7fba5b2ea9e8>]},
#                       <heap.MinHeap at 0x7fba5b7b22b0>]},
#                     <heap.MinHeap at 0x7fba5b7b2390>]},
#                   <heap.MinHeap at 0x7fba5b786b38>]},
#                 <heap.MinHeap at 0x7fba5b786828>]},
#               <heap.MinHeap at 0x7fba5b786ac8>]},
#             <heap.MinHeap at 0x7fba5b7866a0>]},
#           <heap.MinHeap at 0x7fba5b7864a8>]},
#         <heap.MinHeap at 0x7fba5b7861d0>]},
#       <heap.MinHeap at 0x7fba5b786e80>]},
#     <heap.MinHeap at 0x7fba5b786a58>]},
#   <heap.MinHeap at 0x7fba5b3ebeb8>],
#  'Н': [{'е': [{'с': [{'к': [{'у': [{'ч': [{'н': [{'ы': [{'й': [{' ': [{'с': [{'а': [{'д': [{},
#                           <heap.MinHeap at 0x7fba6529e9b0>,
#                           None]},
#                         <heap.MinHeap at 0x7fba6529e320>]},
#                       <heap.MinHeap at 0x7fba5a2aaf60>]},
#                     <heap.MinHeap at 0x7fba5a2aaef0>]},
#                   <heap.MinHeap at 0x7fba5a2aa470>]},
#                 <heap.MinHeap at 0x7fba5a2aa978>]},
#               <heap.MinHeap at 0x7fba5a2aa6a0>]},
#             <heap.MinHeap at 0x7fba5a2aada0>]},
#           <heap.MinHeap at 0x7fba5a2aa438>]},
#         <heap.MinHeap at 0x7fba58847390>]},
#       <heap.MinHeap at 0x7fba54446cf8>]},
#     <heap.MinHeap at 0x7fba54446160>],
#    'и': [{'а': [{'г': [{'а': [{'р': [{'с': [{'к': [{'и': [{'й': [{' ': [{'в': [{'о': [{'д': [{'о': [{'п': [{'а': [{'д': [{},
#                                     <heap.MinHeap at 0x7fba583d07b8>,
#                                     None]},
#                                   <heap.MinHeap at 0x7fba583d0390>]},
#                                 <heap.MinHeap at 0x7fba583d0f60>]},
#                               <heap.MinHeap at 0x7fba583d0eb8>]},
#                             <heap.MinHeap at 0x7fba615d90b8>]},
#                           <heap.MinHeap at 0x7fba615d9358>]},
#                         <heap.MinHeap at 0x7fba59b99a20>]},
#                       <heap.MinHeap at 0x7fba59b996d8>]},
#                     <heap.MinHeap at 0x7fba59b99160>]},
#                   <heap.MinHeap at 0x7fba59b99400>]},
#                 <heap.MinHeap at 0x7fba59b999e8>]},
#               <heap.MinHeap at 0x7fba59b995c0>]},
#             <heap.MinHeap at 0x7fba59b99da0>]},
#           <heap.MinHeap at 0x7fba585ee358>]},
#         <heap.MinHeap at 0x7fba585eee80>]},
#       <heap.MinHeap at 0x7fba585ee518>]},
#     <heap.MinHeap at 0x7fba585eedd8>],
#    'о': [{'р': [{'м': [{'а': [{'н': [{'д': [{'и': [{'я': [{},
#                   <heap.MinHeap at 0x7fba5b94ba90>,
#                   None]},
#                 <heap.MinHeap at 0x7fba5b94b5c0>]},
#               <heap.MinHeap at 0x7fba5b94b668>]},
#             <heap.MinHeap at 0x7fba5b94be48>]},
#           <heap.MinHeap at 0x7fba5b94be10>]},
#         <heap.MinHeap at 0x7fba5b94bc18>]},
#       <heap.MinHeap at 0x7fba5b94bd68>]},
#     <heap.MinHeap at 0x7fba5b94b2e8>]},
#   <heap.MinHeap at 0x7fba5b94bda0>],
#  'О': [{'з': [{'е': [{'р': [{'о': [{' ': [{'Б': [{'а': [{'й': [{'к': [{'а': [{'л': [{},
#                         <heap.MinHeap at 0x7fba5bdeb780>,
#                         None]},
#                       <heap.MinHeap at 0x7fba5bdebda0>]},
#                     <heap.MinHeap at 0x7fba5bdebb00>]},
#                   <heap.MinHeap at 0x7fba5bdebe48>]},
#                 <heap.MinHeap at 0x7fba53d00208>]},
#               <heap.MinHeap at 0x7fba53d00160>],
#              'Х': [{'е': [{'в': [{'и': [{'з': [{},
#                       <heap.MinHeap at 0x7fba54efd358>,
#                       None]},
#                     <heap.MinHeap at 0x7fba54efd198>]},
#                   <heap.MinHeap at 0x7fba54efd6a0>]},
#                 <heap.MinHeap at 0x7fba54efdda0>]},
#               <heap.MinHeap at 0x7fba54efd240>]},
#             <heap.MinHeap at 0x7fba5962be48>]},
#           <heap.MinHeap at 0x7fba5962b320>]},
#         <heap.MinHeap at 0x7fba5bd99dd8>]},
#       <heap.MinHeap at 0x7fba5bd99f28>]},
#     <heap.MinHeap at 0x7fba5bd99f60>],
#    'п': [{'т': [{'и': [{'н': [{'а': [{' ': [{'п': [{'у': [{'с': [{'т': [{'ы': [{'н': [{'ь': [{},
#                             <heap.MinHeap at 0x7fba59bed748>,
#                             None]},
#                           <heap.MinHeap at 0x7fba59bed7f0>]},
#                         <heap.MinHeap at 0x7fba59bed470>]},
#                       <heap.MinHeap at 0x7fba59bed160>]},
#                     <heap.MinHeap at 0x7fba59bed9b0>]},
#                   <heap.MinHeap at 0x7fba5a45d400>]},
#                 <heap.MinHeap at 0x7fba5a45d940>]},
#               <heap.MinHeap at 0x7fba5a45d828>]},
#             <heap.MinHeap at 0x7fba5a45d710>]},
#           <heap.MinHeap at 0x7fba5a45d3c8>]},
#         <heap.MinHeap at 0x7fba5a45dc50>]},
#       <heap.MinHeap at 0x7fba5a45dc88>]},
#     <heap.MinHeap at 0x7fba5a45ddd8>],
#    'с': [{'т': [{'р': [{'о': [{'в': [{' ': [{'К': [{'р': [{'и': [{'т': [{},
#                       <heap.MinHeap at 0x7fba5b5c8588>,
#                       None]},
#                     <heap.MinHeap at 0x7fba5bda4dd8>]},
#                   <heap.MinHeap at 0x7fba5bda4e80>]},
#                 <heap.MinHeap at 0x7fba5bda4160>],
#                'П': [{'а': [{'с': [{'х': [{'и': [{},
#                         <heap.MinHeap at 0x7fba638e86a0>,
#                         None]},
#                       <heap.MinHeap at 0x7fba638e8160>]},
#                     <heap.MinHeap at 0x7fba638e8fd0>]},
#                   <heap.MinHeap at 0x7fba638e84a8>],
#                  'х': [{'у': [{'к': [{'е': [{'т': [{},
#                           <heap.MinHeap at 0x7fba6529aba8>,
#                           None]},
#                         <heap.MinHeap at 0x7fba6529a940>]},
#                       <heap.MinHeap at 0x7fba5961eb00>]},
#                     <heap.MinHeap at 0x7fba5961e7f0>]},
#                   <heap.MinHeap at 0x7fba52dc8128>]},
#                 <heap.MinHeap at 0x7fba638e89e8>],
#                'Х': [{'а': [{'й': [{'н': [{'а': [{'н': [{'ь': [{},
#                             <heap.MinHeap at 0x7fba5a864400>,
#                             None]},
#                           <heap.MinHeap at 0x7fba5a27f9b0>]},
#                         <heap.MinHeap at 0x7fba5a27ff28>]},
#                       <heap.MinHeap at 0x7fba5a27fe48>]},
#                     <heap.MinHeap at 0x7fba5a27fb38>]},
# ...
#                                     <heap.MinHeap at 0x7fba585c0048>]},
#                                   <heap.MinHeap at 0x7fba585c0e10>]},
#                                 <heap.MinHeap at 0x7fba585c0b38>]},
#                               <heap.MinHeap at 0x7fba585c0908>]},
#                             <heap.MinHeap at 0x7fba585c0668>]},
#                           <heap.MinHeap at 0x7fba5bd91ef0>]},
#                         <heap.MinHeap at 0x7fba5bd91fd0>]},
#                       <heap.MinHeap at 0x7fba5bd91a90>]},
#                     <heap.MinHeap at 0x7fba5bd91828>]},
#                   <heap.MinHeap at 0x7fba596deb38>]},
#                 <heap.MinHeap at 0x7fba596dedd8>]},
#               <heap.MinHeap at 0x7fba596dec88>],
#              'С': [{'в': [{'я': [{'т': [{'о': [{'г': [{'о': [{' ': [{'П': [{'е': [{'т': [{'р': [{'а': [{},
#                                       <heap.MinHeap at 0x7fba599367f0>,
#                                       None]},
#                                     <heap.MinHeap at 0x7fba59936588>]},
#                                   <heap.MinHeap at 0x7fba59936dd8>]},
#                                 <heap.MinHeap at 0x7fba599364a8>]},
#                               <heap.MinHeap at 0x7fba59936358>]},
#                             <heap.MinHeap at 0x7fba59936a58>]},
#                           <heap.MinHeap at 0x7fba59936160>]},
#                         <heap.MinHeap at 0x7fba59699b38>]},
#                       <heap.MinHeap at 0x7fba59699da0>]},
#                     <heap.MinHeap at 0x7fba59699860>]},
#                   <heap.MinHeap at 0x7fba59699c88>]},
#                 <heap.MinHeap at 0x7fba5a4c2550>]},
#               <heap.MinHeap at 0x7fba5a4c2f60>]},
#             <heap.MinHeap at 0x7fba596de9e8>]},
#           <heap.MinHeap at 0x7fba596deac8>]},
#         <heap.MinHeap at 0x7fba596de668>]},
#       <heap.MinHeap at 0x7fba5bdeb7f0>],
#      'л': [{'н': [{'е': [{'ч': [{'н': [{'ы': [{'й': [{' ': [{'б': [{'е': [{'р': [{'е': [{'г': [{},
#                               <heap.MinHeap at 0x7fba583cb978>,
#                               None]},
#                             <heap.MinHeap at 0x7fba583cb2e8>]},
#                           <heap.MinHeap at 0x7fba583cb080>]},
#                         <heap.MinHeap at 0x7fba583cb588>]},
#                       <heap.MinHeap at 0x7fba583cbac8>]},
#                     <heap.MinHeap at 0x7fba5c1c10b8>]},
#                   <heap.MinHeap at 0x7fba5c1c1240>]},
#                 <heap.MinHeap at 0x7fba5a2e6be0>]},
#               <heap.MinHeap at 0x7fba5a2e6f28>]},
#             <heap.MinHeap at 0x7fba5a2e6b00>]},
#           <heap.MinHeap at 0x7fba5cf1d438>]},
#         <heap.MinHeap at 0x7fba5cf1d898>]},
#       <heap.MinHeap at 0x7fba5b9be470>]},
#     <heap.MinHeap at 0x7fba5b9be940>],
#    'т': [{'а': [{'т': [{'у': [{'я': [{' ': [{'С': [{'в': [{'о': [{'б': [{'о': [{'д': [{'ы': [{' ': [{'(': [{'S': [{'t': [{'a': [{'t': [{'u': [{'e': [{' ': [{'o': [{'f': [{' ': [{'L': [{'i': [{'b': [{'e': [{'r': [{'t': [{'y': [{')': [{},
#                                                                     <heap.MinHeap at 0x7fba64e70828>,
#                                                                     None]},
#                                                                   <heap.MinHeap at 0x7fba64e70240>]},
#                                                                 <heap.MinHeap at 0x7fba64e70128>]},
#                                                               <heap.MinHeap at 0x7fba64e70390>]},
#                                                             <heap.MinHeap at 0x7fba64e70a20>]},
#                                                           <heap.MinHeap at 0x7fba5c230b70>]},
#                                                         <heap.MinHeap at 0x7fba5b5ddd30>]},
#                                                       <heap.MinHeap at 0x7fba5b5ddfd0>]},
#                                                     <heap.MinHeap at 0x7fba5b5dd0b8>]},
#                                                   <heap.MinHeap at 0x7fba5b5dda90>]},
#                                                 <heap.MinHeap at 0x7fba5b5dd8d0>]},
#                                               <heap.MinHeap at 0x7fba5b5dd748>]},
#                                             <heap.MinHeap at 0x7fba5bdef5c0>]},
#                                           <heap.MinHeap at 0x7fba5bdefb00>]},
#                                         <heap.MinHeap at 0x7fba5bdefb38>]},
#                                       <heap.MinHeap at 0x7fba5bdef550>]},
#                                     <heap.MinHeap at 0x7fba5bdef8d0>]},
#                                   <heap.MinHeap at 0x7fba5bdef588>]},
#                                 <heap.MinHeap at 0x7fba59bf0978>]},
#                               <heap.MinHeap at 0x7fba59bf07b8>]},
#                             <heap.MinHeap at 0x7fba59bf0860>]},
#                           <heap.MinHeap at 0x7fba59bf0630>]},
#                         <heap.MinHeap at 0x7fba59bf0358>]},
#                       <heap.MinHeap at 0x7fba59bf0f98>]},
#                     <heap.MinHeap at 0x7fba585cc358>]},
#                   <heap.MinHeap at 0x7fba585cca58>]},
#                 <heap.MinHeap at 0x7fba585ccef0>]},
#               <heap.MinHeap at 0x7fba5be7b8d0>]},
#             <heap.MinHeap at 0x7fba5be7b358>]},
#           <heap.MinHeap at 0x7fba5be7b748>]},
#         <heap.MinHeap at 0x7fba5be7bf98>]},
#       <heap.MinHeap at 0x7fba5be7b828>],
#      'е': [{'н': [{'а': [{' ': [{'П': [{'л': [{'а': [{'ч': [{'а': [{},
#                       <heap.MinHeap at 0x7fba5b39b748>,
#                       None]},
#                     <heap.MinHeap at 0x7fba5b39b2e8>]},
#                   <heap.MinHeap at 0x7fba5b39b198>]},
#                 <heap.MinHeap at 0x7fba59bd4cc0>]},
#               <heap.MinHeap at 0x7fba59bd4048>]},
#             <heap.MinHeap at 0x7fba59bd45c0>]},
#           <heap.MinHeap at 0x7fba59bd44e0>]},
#         <heap.MinHeap at 0x7fba638ed400>]},
#       <heap.MinHeap at 0x7fba638ed940>],
#      'о': [{'у': [{'н': [{'х': [{'е': [{'н': [{'д': [{'ж': [{},
#                     <heap.MinHeap at 0x7fba53d6e6a0>,
#                     None]},
#                   <heap.MinHeap at 0x7fba53d6e080>]},
#                 <heap.MinHeap at 0x7fba585fb198>]},
#               <heap.MinHeap at 0x7fba585fb8d0>]},
#             <heap.MinHeap at 0x7fba585fb518>]},
#           <heap.MinHeap at 0x7fba585fb0f0>]},
#         <heap.MinHeap at 0x7fba585fb4e0>]},
#       <heap.MinHeap at 0x7fba5b39bd30>]},
#     <heap.MinHeap at 0x7fba5be7bc18>],
#    'ф': [{'и': [{'н': [{'к': [{'с': [{},
#             <heap.MinHeap at 0x7fba5b2dc7b8>,
#             None]},
#           <heap.MinHeap at 0x7fba5b2dc3c8>]},
#         <heap.MinHeap at 0x7fba5b2dc048>]},
#       <heap.MinHeap at 0x7fba5b2dcac8>]},
#     <heap.MinHeap at 0x7fba64e6c278>]},
#   <heap.MinHeap at 0x7fba5b3f0e48>],
#  'Т': [{'а': [{'д': [{'ж': [{'-': [{'М': [{'а': [{'х': [{'а': [{'л': [{},
#                     <heap.MinHeap at 0x7fba5b3f4160>,
#                     None]},
#                   <heap.MinHeap at 0x7fba5b3f43c8>]},
#                 <heap.MinHeap at 0x7fba5b3f49b0>]},
#               <heap.MinHeap at 0x7fba5b3f4fd0>]},
#             <heap.MinHeap at 0x7fba5b3f4d30>]},
#           <heap.MinHeap at 0x7fba5b3f4be0>]},
#         <heap.MinHeap at 0x7fba5b3f4588>]},
#       <heap.MinHeap at 0x7fba5b3f4668>]},
#     <heap.MinHeap at 0x7fba64e70d68>],
#    'е': [{'н': [{'е': [{'р': [{'и': [{'ф': [{'е': [{},
#                 <heap.MinHeap at 0x7fba5b93bf60>,
#                 None]},
#               <heap.MinHeap at 0x7fba5b93bd30>]},
#             <heap.MinHeap at 0x7fba6529ada0>]},
#           <heap.MinHeap at 0x7fba6529ab00>]},
#         <heap.MinHeap at 0x7fba6529a3c8>]},
#       <heap.MinHeap at 0x7fba6529aef0>]},
#     <heap.MinHeap at 0x7fba6529a710>],
#    'и': [{'б': [{'е': [{'т': [{}, <heap.MinHeap at 0x7fba64e676d8>, None]},
#         <heap.MinHeap at 0x7fba5af60908>]},
#       <heap.MinHeap at 0x7fba5af60438>]},
#     <heap.MinHeap at 0x7fba5af608d0>],
#    'р': [{'а': [{'н': [{'с': [{'и': [{'л': [{'ь': [{'в': [{'а': [{'н': [{'и': [{'я': [{},
#                           <heap.MinHeap at 0x7fba584df978>,
#                           None]},
#                         <heap.MinHeap at 0x7fba584df908>]},
#                       <heap.MinHeap at 0x7fba584df748>]},
#                     <heap.MinHeap at 0x7fba584df5c0>]},
#                   <heap.MinHeap at 0x7fba584df240>]},
#                 <heap.MinHeap at 0x7fba584df198>]},
#               <heap.MinHeap at 0x7fba59635c88>]},
#             <heap.MinHeap at 0x7fba59635898>]},
#           <heap.MinHeap at 0x7fba5e64e550>]},
#         <heap.MinHeap at 0x7fba5e64ef28>]},
#       <heap.MinHeap at 0x7fba53d6eda0>],
#      'е': [{'т': [{'ь': [{'я': [{'к': [{'о': [{'в': [{'с': [{'к': [{'а': [{'я': [{' ': [{'г': [{'а': [{'л': [{'е': [{'р': [{'е': [{'я': [{},
#                                           <heap.MinHeap at 0x7fba5a2eb390>,
#                                           None]},
#                                         <heap.MinHeap at 0x7fba5a2ebdd8>]},
#                                       <heap.MinHeap at 0x7fba5a2eb710>]},
#                                     <heap.MinHeap at 0x7fba59bf6898>]},
#                                   <heap.MinHeap at 0x7fba59bf62b0>]},
#                                 <heap.MinHeap at 0x7fba5c6854e0>]},
#                               <heap.MinHeap at 0x7fba5c685550>]},
#                             <heap.MinHeap at 0x7fba5c685320>]},
#                           <heap.MinHeap at 0x7fba5c685eb8>]},
#                         <heap.MinHeap at 0x7fba5c685a20>]},
#                       <heap.MinHeap at 0x7fba5c685828>]},
#                     <heap.MinHeap at 0x7fba5a4e51d0>]},
#                   <heap.MinHeap at 0x7fba5a4e5400>]},
#                 <heap.MinHeap at 0x7fba5a4e5908>]},
#               <heap.MinHeap at 0x7fba5a4e5c18>]},
#             <heap.MinHeap at 0x7fba5a4e5710>]},
#           <heap.MinHeap at 0x7fba5a4e5ac8>]},
#         <heap.MinHeap at 0x7fba5a4e5f60>]},
#       <heap.MinHeap at 0x7fba5a4e52e8>]},
#     <heap.MinHeap at 0x7fba53d6eba8>]},
#   <heap.MinHeap at 0x7fba5b3f0898>],
#  'У': [{'о': [{'л': [{'л': [{'-': [{'с': [{'т': [{'р': [{'и': [{'т': [{},
#                     <heap.MinHeap at 0x7fba636f1710>,
#                     None]},
#                   <heap.MinHeap at 0x7fba584f8eb8>]},
#                 <heap.MinHeap at 0x7fba584f8860>]},
#               <heap.MinHeap at 0x7fba584f8b70>]},
#             <heap.MinHeap at 0x7fba584f8d68>]},
#           <heap.MinHeap at 0x7fba584f85c0>]},
#         <heap.MinHeap at 0x7fba584f8358>]},
#       <heap.MinHeap at 0x7fba584f8198>]},
#     <heap.MinHeap at 0x7fba5a4cdcf8>]},
#   <heap.MinHeap at 0x7fba5a4cd978>],
#  'Ф': [{'о': [{'р': [{'т': [{' ': [{'Б': [{'о': [{'я': [{'р': [{'д': [{},
#                     <heap.MinHeap at 0x7fba53d68d30>,
#                     None]},
#                   <heap.MinHeap at 0x7fba53d681d0>]},
#                 <heap.MinHeap at 0x7fba53d684a8>]},
#               <heap.MinHeap at 0x7fba53d68128>]},
#             <heap.MinHeap at 0x7fba5b90d080>]},
#           <heap.MinHeap at 0x7fba5b90dac8>]},
#         <heap.MinHeap at 0x7fba5444a240>]},
#       <heap.MinHeap at 0x7fba5444ae10>]},
#     <heap.MinHeap at 0x7fba5444a588>]},
#   <heap.MinHeap at 0x7fba5444a6a0>],
#  'Х': [{'р': [{'а': [{'м': [{' ': [{'В': [{'а': [{'с': [{'и': [{'л': [{'и': [{'я': [{' ': [{'Б': [{'л': [{'а': [{'ж': [{'е': [{'н': [{'н': [{'о': [{'г': [{'о': [{},
#                                               <heap.MinHeap at 0x7fba585dc240>,
#                                               None]},
#                                             <heap.MinHeap at 0x7fba585dc8d0>]},
#                                           <heap.MinHeap at 0x7fba677402b0>]},
#                                         <heap.MinHeap at 0x7fba67740710>]},
#                                       <heap.MinHeap at 0x7fba544deb00>]},
#                                     <heap.MinHeap at 0x7fba544dee80>]},
#                                   <heap.MinHeap at 0x7fba544de7f0>]},
#                                 <heap.MinHeap at 0x7fba544decf8>]},
#                               <heap.MinHeap at 0x7fba544de358>]},
#                             <heap.MinHeap at 0x7fba593d9da0>]},
#                           <heap.MinHeap at 0x7fba593d9b38>]},
#                         <heap.MinHeap at 0x7fba593d9978>]},
#                       <heap.MinHeap at 0x7fba593d97f0>]},
#                     <heap.MinHeap at 0x7fba593d9470>]},
#                   <heap.MinHeap at 0x7fba593d90f0>]},
#                 <heap.MinHeap at 0x7fba661a1978>]},
#               <heap.MinHeap at 0x7fba661a1080>]},
#             <heap.MinHeap at 0x7fba661a14e0>],
#            'Х': [{'р': [{'и': [{'с': [{'т': [{'а': [{' ': [{'С': [{'п': [{'а': [{'с': [{'и': [{'т': [{'е': [{'л': [{'я': [{},
#                                           <heap.MinHeap at 0x7fba636e9d30>,
#                                           None]},
#                                         <heap.MinHeap at 0x7fba636e91d0>]},
#                                       <heap.MinHeap at 0x7fba636e9a58>]},
#                                     <heap.MinHeap at 0x7fba636e9ef0>]},
#                                   <heap.MinHeap at 0x7fba636e9c18>]},
#                                 <heap.MinHeap at 0x7fba636e9dd8>]},
#                               <heap.MinHeap at 0x7fba58b05978>]},
#                             <heap.MinHeap at 0x7fba588644e0>]},
#                           <heap.MinHeap at 0x7fba58864780>]},
#                         <heap.MinHeap at 0x7fba5b3d6630>]},
#                       <heap.MinHeap at 0x7fba5b3d60b8>]},
#                     <heap.MinHeap at 0x7fba5b3d6978>]},
#                   <heap.MinHeap at 0x7fba5b3d6be0>]},
#                 <heap.MinHeap at 0x7fba584d79b0>]},
#               <heap.MinHeap at 0x7fba584d7710>]},
#             <heap.MinHeap at 0x7fba584d7438>]},
#           <heap.MinHeap at 0x7fba661a18d0>]},
#         <heap.MinHeap at 0x7fba661a1940>]},
#       <heap.MinHeap at 0x7fba661a1d68>]},
#     <heap.MinHeap at 0x7fba661a1400>]},
#   <heap.MinHeap at 0x7fba661a1b00>],
#  'Ш': [{'о': [{'т': [{'л': [{'а': [{'н': [{'д': [{'и': [{'я': [{},
#                   <heap.MinHeap at 0x7fba59936f98>,
#                   None]},
#                 <heap.MinHeap at 0x7fba59936908>]},
#               <heap.MinHeap at 0x7fba59936cf8>]},
#             <heap.MinHeap at 0x7fba59936b38>]},
#           <heap.MinHeap at 0x7fba59936080>]},
#         <heap.MinHeap at 0x7fba59936a90>]},
#       <heap.MinHeap at 0x7fba59936ac8>]},
#     <heap.MinHeap at 0x7fba599362b0>]},
#   <heap.MinHeap at 0x7fba59936978>],
#  'Э': [{'в': [{'е': [{'р': [{'е': [{'с': [{'т': [{},
#               <heap.MinHeap at 0x7fba66197828>,
#               None]},
#             <heap.MinHeap at 0x7fba661970f0>]},
#           <heap.MinHeap at 0x7fba66197278>]},
#         <heap.MinHeap at 0x7fba66197eb8>]},
#       <heap.MinHeap at 0x7fba661976d8>]},
#     <heap.MinHeap at 0x7fba66197518>],
#    'й': [{'ф': [{'е': [{'л': [{'е': [{'в': [{'а': [{' ': [{'б': [{'а': [{'ш': [{'н': [{'я': [{},
#                             <heap.MinHeap at 0x7fba584ce4e0>,
#                             None]},
#                           <heap.MinHeap at 0x7fba64e0ca90>]},
#                         <heap.MinHeap at 0x7fba64e0c9e8>]},
#                       <heap.MinHeap at 0x7fba64e0c1d0>]},
#                     <heap.MinHeap at 0x7fba64e0c828>]},
#                   <heap.MinHeap at 0x7fba64e0c710>]},
#                 <heap.MinHeap at 0x7fba64e0c240>]},
#               <heap.MinHeap at 0x7fba64e0cda0>]},
#             <heap.MinHeap at 0x7fba64e0c668>]},
#           <heap.MinHeap at 0x7fba64e67ba8>]},
#         <heap.MinHeap at 0x7fba64e674e0>]},
#       <heap.MinHeap at 0x7fba64e67a58>]},
#     <heap.MinHeap at 0x7fba64e67278>],
#    'л': [{'ь': [{'б': [{'р': [{'у': [{'с': [{},
#               <heap.MinHeap at 0x7fba5ad6a908>,
#               None]},
#             <heap.MinHeap at 0x7fba5cb14c88>]},
#           <heap.MinHeap at 0x7fba5cb14a58>]},
#         <heap.MinHeap at 0x7fba5cb147f0>]},
#       <heap.MinHeap at 0x7fba5cb14f98>]},
#     <heap.MinHeap at 0x7fba5cb142b0>]},
#   <heap.MinHeap at 0x7fba64e67828>]}

# %%
@app.route("/get_sudgest/<string>", methods=['GET', 'POST'])
def return_sudgest(string):
    #TODO по запросу string вернуть json, c топ-10 саджестами, и значениями из нод
    data = pTree.top10(string)
    return jsonify(data)
    

@app.route("/")
def hello():
    #TODO должна возвращатьс инструкция по работе с сервером
    return render_template('hello.html')

if __name__ == "__main__":
    app.run()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-54-45faab0937fd> in <module>()
# ----> 1 @app.route("/get_sudgest/<string>", methods=['GET', 'POST'])
#       2 def return_sudgest(string):
#       3     #TODO по запросу string вернуть json, c топ-10 саджестами, и значениями из нод
#       4     data = pTree.top10(string)
#       5     return jsonify(data)
#
# /home/elizabeth/anaconda3/lib/python3.5/site-packages/flask/app.py in decorator(f)
#    1095         def decorator(f):
#    1096             endpoint = options.pop('endpoint', None)
# -> 1097             self.add_url_rule(rule, endpoint, f, **options)
#    1098             return f
#    1099         return decorator
#
# /home/elizabeth/anaconda3/lib/python3.5/site-packages/flask/app.py in wrapper_func(self, *args, **kwargs)
#      63                 'database models and everything related at a central place '
#      64                 'before the application starts serving requests.')
# ---> 65         return f(self, *args, **kwargs)
#      66     return update_wrapper(wrapper_func, f)
#      67
#
# /home/elizabeth/anaconda3/lib/python3.5/site-packages/flask/app.py in add_url_rule(self, rule, endpoint, view_func, **options)
#    1066             if old_func is not None and old_func != view_func:
#    1067                 raise AssertionError('View function mapping is overwriting an '
# -> 1068                                      'existing endpoint function: %s' % endpoint)
#    1069             self.view_functions[endpoint] = view_func
#    1070
#
# AssertionError: View function mapping is overwriting an existing endpoint function: return_sudgest
